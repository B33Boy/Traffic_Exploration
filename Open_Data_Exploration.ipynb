# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import mplleaflet
import numpy as np
import pandas as pd
import requests
import json

# %% [markdown]
# ## Plotting example

# %%
points = np.array([[43.654337, -79.380689],[43.6435, -79.3810]])

# %%
lat = points[:, 0]
long = points[:, 1]

# %%
fig, ax = plt.subplots()
ax.plot(long, lat, 'rs')

# Display Inline
mplleaflet.display(fig=fig)


# Display HTML 
# mplleaflet.show(fig=fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %% [markdown]
# ## Bike Paths
# https://insights-york.opendata.arcgis.com/datasets/bike-path/geoservice

# %%
resp = requests.get('https://utility.arcgis.com/usrsvcs/servers/19e0783e1b1840129fe066e14369920b/rest/services/OpenData/OD_BIKEROUTES/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

# %%
result = json.loads(resp.text)

# %%
coords = np.empty((0,2), float)
fig, ax = plt.subplots()

for i in range(len(result['features'])):
    coords = np.array((result['features'][i]['geometry']['paths'][0]))
    long = coords[:, 0]
    lat = coords[:, 1]
    ax.plot(long, lat, linewidth=4)

# Display Inline
mplleaflet.display(fig=fig)

# Display HTML
# mplleaflet.show(fig=fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
fig.savefig('bike_paths.png')

# %% [markdown]
# ![title](bike_paths.png)

# %% [markdown]
# ## Traffic Lights

# %%
traffic_req = requests.get('https://ww8.yorkmaps.ca/arcgis/rest/services/OpenData/Traffic/MapServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

# %%
# result = json.loads(traffic_req.text)

# %%
# result

# %%
# print(json.dumps(result3, indent=4, sort_keys=True))
