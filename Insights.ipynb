# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import mplleaflet
import numpy as np
import pandas as pd
import requests
import json

# %%
bus_stops_resp = requests.get('https://opendata.arcgis.com/datasets/ca904f8425814759a3dfa5951afff479_2.geojson')

# %%
bus_stops = json.loads(bus_stops_resp.text)

# %%
bus_stops['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'OBJECTID': 1001,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4692',
#    'CODE': '4692',
#    'STOP_NAME': 'YONGE ST / WRIGHT ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43897999999996, 43.87812100000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1002,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7268',
#    'CODE': '7268',
#    'STOP_NAME': 'MURRELL BLVD / APPLEGATE DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44869399999999, 44.08571200000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1003,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6424',
#    'CODE': '6424',
#    'STOP_NAME': 'AURORA GO STATION PLATFORM 2',
#    'DESCRIPTION': 'AURORA GO STATION & PLATFORM #2',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45949999999993, 44.00016000000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1004,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6425',
#    'CODE': '6425',
#    'STOP_NAME': 'INDUSTRIAL PKWY / YONGE ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46227899999997, 43.98118100000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1005,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6426',
#    'CODE': '6426',
#    'STOP_NAME': 'NEWMARKET GO PLATFORM 10',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48615299999994, 44.05278000000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1006,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1680',
#    'CODE': '1680',
#    'STOP_NAME': 'MAJOR MACKENZIE DR / WOODBINE AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36777999999998, 43.885680000000036]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1007,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6420',
#    'CODE': '6420',
#    'STOP_NAME': 'DUFFIELD DR / KENNEDY RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30663099999998, 43.845769000000075]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1008,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4298',
#    'CODE': '4298',
#    'STOP_NAME': 'HIGHWAY 7 / RODICK RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.34580599999998, 43.852697000000035]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1009,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6422',
#    'CODE': '6422',
#    'STOP_NAME': 'MAIN ST / 10TH LINE',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.23218499999996, 43.97456600000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1010,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6423',
#    'CODE': '6423',
#    'STOP_NAME': 'AURORA GO STATION PLATFORM 3',
#    'DESCRIPTION': 'AURORA GO STATION & PLATFORM #3',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45941099999999, 43.99988100000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1011,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4295',
#    'CODE': '4295',
#    'STOP_NAME': 'ASHBERRY BLVD / WESTON RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55730699999998, 43.83462600000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1012,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4297',
#    'CODE': '4297',
#    'STOP_NAME': 'ASHBERRY BLVD / OLAND DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55473499999994, 43.83509300000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1013,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1423',
#    'CODE': '1423',
#    'STOP_NAME': 'RODICK RD / RACHEL CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36223399999994, 43.877080000000035]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1014,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6428',
#    'CODE': '6428',
#    'STOP_NAME': 'METRO RD / LENNOX AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47218899999996, 44.297308000000044]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1015,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6429',
#    'CODE': '6429',
#    'STOP_NAME': 'HIGH ST / DALTON RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36214299999995, 44.30460000000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1016,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2972',
#    'CODE': '2972',
#    'STOP_NAME': 'RIDGECREST RD / MAJOR MACKENZIE DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30452499999996, 43.90035900000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1017,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6412',
#    'CODE': '6412',
#    'STOP_NAME': 'MULOCK DR / COLUMBUS WAY',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48168899999996, 44.03496000000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1018,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '9851',
#    'CODE': '9851',
#    'STOP_NAME': 'DAVIS DR / LESLIE ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43120399999998, 44.06588400000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1019,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4695',
#    'CODE': '4695',
#    'STOP_NAME': 'YONGE ST / HIGH TECH RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43037999999996, 43.84161700000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1020,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7267',
#    'CODE': '7267',
#    'STOP_NAME': 'JANE ST / FREDERICK BANTING ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.53726499999993, 43.85165400000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1021,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7266',
#    'CODE': '7266',
#    'STOP_NAME': 'JANE ST / FREDERICK BANTING ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.53679399999999, 43.85100900000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1022,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2590',
#    'CODE': '2590',
#    'STOP_NAME': "DAVIS DR / LUNDY'S LANE",
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45361399999996, 44.06091200000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1023,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7261',
#    'CODE': '7261',
#    'STOP_NAME': 'VICTORIA ST / CHURCH ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46515299999999, 43.99718000000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1024,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6169',
#    'CODE': '6169',
#    'STOP_NAME': 'YONGE ST / HOMEWOOD AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41862499999996, 43.79128900000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1025,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6168',
#    'CODE': '6168',
#    'STOP_NAME': 'WOODBINE AV / ELGIN MILLS RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37825799999996, 43.903001000000074]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1026,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6161',
#    'CODE': '6161',
#    'STOP_NAME': 'HAZELTON AV / VINE CLIFF BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36592199999996, 43.893770000000075]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1027,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1971',
#    'CODE': '1971',
#    'STOP_NAME': 'UPPER CANADA MALL STOP # 1971',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48616999999996, 44.054512000000045]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1028,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6163',
#    'CODE': '6163',
#    'STOP_NAME': 'STONY HILL BLVD / VICTORIA SQUARE B',
#    'DESCRIPTION': 'STONY HILL BLVD & VICTORIA SQUARE BLVD',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36952999999994, 43.89677800000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1029,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6162',
#    'CODE': '6162',
#    'STOP_NAME': 'HAZELTON AV / STONY HILL BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36760799999996, 43.896948000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1030,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6165',
#    'CODE': '6165',
#    'STOP_NAME': 'WOODBINE AV / PRINCE OF WALES',
#    'DESCRIPTION': 'WOODBINE AV & PRINCE OF WALES DR',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37893799999995, 43.90532600000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1031,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6167',
#    'CODE': '6167',
#    'STOP_NAME': 'WOODBINE AV / LORD MELBORNE ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37952799999994, 43.905808000000036]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1032,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6166',
#    'CODE': '6166',
#    'STOP_NAME': 'HONDA STOP # 6166',
#    'DESCRIPTION': 'HONDA PLANT & BESIDE MAIN ENTRANCE',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.38411999999994, 43.91359700000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1033,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4749',
#    'CODE': '4749',
#    'STOP_NAME': 'WELLINGTON ST / WELLS ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46392099999997, 44.00048900000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1034,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4748',
#    'CODE': '4748',
#    'STOP_NAME': 'WELLINGTON ST / MCDONALD DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48000899999994, 43.99704600000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1035,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6769',
#    'CODE': '6769',
#    'STOP_NAME': 'BAYVIEW AV / SUMMIT TRAIL DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42553399999997, 43.91732500000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1036,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6768',
#    'CODE': '6768',
#    'STOP_NAME': 'CALDARI RD / GRANITERIDGE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.52996899999994, 43.82551600000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1037,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4743',
#    'CODE': '4743',
#    'STOP_NAME': 'CONOVER AV / STARR CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44397399999997, 44.01799300000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1038,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4742',
#    'CODE': '4742',
#    'STOP_NAME': 'HARTWELL WAY / BAYVIEW AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44656699999996, 44.019296000000054]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1039,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4741',
#    'CODE': '4741',
#    'STOP_NAME': 'BAYVIEW AV / HARTWELL WAY',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44673299999994, 44.018976000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1040,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4740',
#    'CODE': '4740',
#    'STOP_NAME': 'GATEWAY DR / KIRKVALLEY CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45486499999998, 44.01697900000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1041,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4747',
#    'CODE': '4747',
#    'STOP_NAME': 'WELLINGTON ST / HILLDALE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48308899999995, 43.99638100000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1042,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4746',
#    'CODE': '4746',
#    'STOP_NAME': 'WELLINGTON ST / MCLEOD DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48670399999997, 43.99563900000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1043,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4745',
#    'CODE': '4745',
#    'STOP_NAME': 'WELLINGTON ST / BATHURST ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49287799999996, 43.994429000000025]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1044,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4744',
#    'CODE': '4744',
#    'STOP_NAME': 'CONOVER AV / BROOKS AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44286399999999, 44.01456300000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1045,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6887',
#    'CODE': '6887',
#    'STOP_NAME': 'KEELE ST STOP # 6887',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.51552899999996, 43.86931400000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1046,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7291',
#    'CODE': '7291',
#    'STOP_NAME': 'HIGHWAY 7 / WHITMORE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55647599999998, 43.78742700000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1047,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5869',
#    'CODE': '5869',
#    'STOP_NAME': 'WESTON RD / MAJOR MACKENZIE DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.56057999999996, 43.84417300000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1048,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5868',
#    'CODE': '5868',
#    'STOP_NAME': 'RUTHERFORD RD / CRIMSON FOREST DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47632499999997, 43.844183000000044]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1049,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4697',
#    'CODE': '4697',
#    'STOP_NAME': 'HIGHWAY 7 STOP # 4697',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.23910499999994, 43.87889400000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1050,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '5865',
#    'CODE': '5865',
#    'STOP_NAME': 'LARKIN AV / SAWYER CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24041999999997, 43.89343900000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1051,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6200',
#    'CODE': '6200',
#    'STOP_NAME': 'ZENWAY BLVD / NEW HUNTINGTON RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.64421199999998, 43.77495400000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1052,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5867',
#    'CODE': '5867',
#    'STOP_NAME': 'RUTHERFORD RD / BLUE GROUSE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47303999999997, 43.84485100000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1053,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '5866',
#    'CODE': '5866',
#    'STOP_NAME': 'RAVENSHOE RD STOP # 5866',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47220099999998, 44.191636000000074]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1054,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5861',
#    'CODE': '5861',
#    'STOP_NAME': 'WOODSPRING AV / FORD WILSON BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49945499999995, 44.05617900000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1055,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '5860',
#    'CODE': '5860',
#    'STOP_NAME': 'METRO RD / GARDEN AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46764299999995, 44.23523200000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1056,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5863',
#    'CODE': '5863',
#    'STOP_NAME': 'ELGIN MILLS RD / PRINCE REGENT ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37515399999995, 43.90325100000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1057,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5862',
#    'CODE': '5862',
#    'STOP_NAME': 'WOODSPRING AV / ART WEST AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49974599999996, 44.05625400000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1058,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6950',
#    'CODE': '6950',
#    'STOP_NAME': 'DAVIS DR / FORHAN AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42991199999994, 44.06611600000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1059,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1424',
#    'CODE': '1424',
#    'STOP_NAME': 'CLARK AV / HILDA AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43708899999996, 43.80553500000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1060,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2331',
#    'CODE': '2331',
#    'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 11',
#    'DESCRIPTION': 'PLATFORM # 11',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41551199999998, 43.782425000000046]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1061,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5350',
#    'CODE': '5350',
#    'STOP_NAME': 'PEARSON AV STOP # 5350',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43706499999996, 43.83926800000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1062,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6796',
#    'CODE': '6796',
#    'STOP_NAME': 'METRO RD / CHARLES CRES',
#    'DESCRIPTION': 'METRO RD & NEW FOREST LN',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48486299999996, 44.25802900000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1063,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2183',
#    'CODE': '2183',
#    'STOP_NAME': 'WELDRICK RD STOP # 2183',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43257699999998, 43.860876000000076]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1064,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2333',
#    'CODE': '2333',
#    'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 14',
#    'DESCRIPTION': 'PLATFORM # 14',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41530499999999, 43.78250300000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1065,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2187',
#    'CODE': '2187',
#    'STOP_NAME': 'ESSEX AV / PALISER CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42314899999997, 43.86872600000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1066,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2186',
#    'CODE': '2186',
#    'STOP_NAME': 'WELDRICK RD / ESSEX AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42182899999995, 43.86697600000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1067,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2185',
#    'CODE': '2185',
#    'STOP_NAME': 'WELDRICK RD STOP # 2185',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42718999999994, 43.86579300000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1068,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2184',
#    'CODE': '2184',
#    'STOP_NAME': 'WELDRICK RD / CHURCH ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43135299999994, 43.863215000000025]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1069,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2189',
#    'CODE': '2189',
#    'STOP_NAME': 'ESSEX AV / ELMWOOD AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42370799999998, 43.87204100000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1070,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2188',
#    'CODE': '2188',
#    'STOP_NAME': 'ESSEX AV / PALMER AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42356599999994, 43.870179000000064]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1071,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4602',
#    'CODE': '4602',
#    'STOP_NAME': 'TIERRA AV / TREASURE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.54410699999994, 43.85646900000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1072,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4603',
#    'CODE': '4603',
#    'STOP_NAME': 'SILVERWOOD AV / YORKLAND ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44033499999995, 43.899402000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1073,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '4600',
#    'CODE': '4600',
#    'STOP_NAME': 'MAPLE SUGAR LANE / THORNHILL WOODS',
#    'DESCRIPTION': 'MAPLE SUGAR LANE & THORNHILL WOODS DR',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46486599999997, 43.82700500000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1074,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2335',
#    'CODE': '2335',
#    'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 16',
#    'DESCRIPTION': 'PLATFORM # 16',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41463199999998, 43.782515000000046]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1075,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2213',
#    'CODE': '2213',
#    'STOP_NAME': 'INDUSTRIAL PKWY / ENGLEHARD DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45386499999995, 43.990368000000046]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1076,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2212',
#    'CODE': '2212',
#    'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2212',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45498099999998, 43.99276700000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1077,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2211',
#    'CODE': '2211',
#    'STOP_NAME': 'INDUSTRIAL PKWY / MARY ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45862599999998, 43.99863700000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1078,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2210',
#    'CODE': '2210',
#    'STOP_NAME': 'ELGIN MILLS RD / REGENT ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45250999999996, 43.88715200000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1079,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2216',
#    'CODE': '2216',
#    'STOP_NAME': 'INDUSTRIAL PKWY / VANDORF SDRD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45547499999998, 43.98363200000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1080,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2215',
#    'CODE': '2215',
#    'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2215',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45436899999999, 43.98609800000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1081,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2214',
#    'CODE': '2214',
#    'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2214',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45353799999998, 43.98822700000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1082,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2680',
#    'CODE': '2680',
#    'STOP_NAME': 'ROLLINGHILL RD / SKYWOOD DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45962399999996, 43.91119400000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1083,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2219',
#    'CODE': '2219',
#    'STOP_NAME': 'BAYVIEW AV / SPRING FARM RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44593099999997, 44.015370000000075]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1084,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6453',
#    'CODE': '6453',
#    'STOP_NAME': 'METRO RD / RAINES ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49763899999994, 44.27209000000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1085,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6209',
#    'CODE': '6209',
#    'STOP_NAME': 'OLD COLONY RD / CAROUSEL CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45289299999996, 43.93990500000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1086,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2338',
#    'CODE': '2338',
#    'STOP_NAME': 'YONGE ST / CUMMER AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41733499999998, 43.787532000000056]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1087,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6699',
#    'CODE': '6699',
#    'STOP_NAME': 'HIGHWAY 50 / RUTHERFORD RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.66726499999999, 43.80321500000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1088,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6698',
#    'CODE': '6698',
#    'STOP_NAME': 'HOLLANDVIEW TRL / BRIDGENORTH DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45304299999998, 44.01370200000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1089,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2339',
#    'CODE': '2339',
#    'STOP_NAME': 'YONGE ST / OTONABEE AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41899399999994, 43.794272000000035]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1090,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6693',
#    'CODE': '6693',
#    'STOP_NAME': 'ILAN RAMON BLVD / GEORGE KIRBY ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46304899999996, 43.84998000000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1091,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6692',
#    'CODE': '6692',
#    'STOP_NAME': 'BOX GROVE BYPASS / 14TH AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22446899999994, 43.861015000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1092,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6691',
#    'CODE': '6691',
#    'STOP_NAME': 'THE BRIDLE WALK / MADISON HEIGHTS',
#    'DESCRIPTION': 'THE BRIDLE WAK & MADISON HEIGHTS BLVD',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30440299999998, 43.89042400000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1093,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6690',
#    'CODE': '6690',
#    'STOP_NAME': 'THE BRIDLE WALK / HOLST AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30379599999998, 43.88957700000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1094,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6697',
#    'CODE': '6697',
#    'STOP_NAME': 'JANE ST STOP # 6697',
#    'DESCRIPTION': 'JANE ST & RUTHERFORD RD',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.53341099999994, 43.83319700000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1095,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6696',
#    'CODE': '6696',
#    'STOP_NAME': 'JANE ST / RUTHERFORD RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.53295999999995, 43.83299000000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1096,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6695',
#    'CODE': '6695',
#    'STOP_NAME': 'ILAN RAMON BLVD / RUTHERFORD RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46233599999994, 43.84812400000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1097,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6694',
#    'CODE': '6694',
#    'STOP_NAME': 'ILAN RAMON BLVD / MARC SANTI BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46364899999998, 43.85164000000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1098,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1426',
#    'CODE': '1426',
#    'STOP_NAME': 'CLARK AV / CHARLES ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43329199999994, 43.80640800000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1099,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2439',
#    'CODE': '2439',
#    'STOP_NAME': 'MULOCK DR / YONGE ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47628799999995, 44.03608900000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1100,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '9856',
#    'CODE': '9856',
#    'STOP_NAME': 'DAVIS DR / HIGHWAY 404',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42110399999996, 44.06762700000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1101,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2195',
#    'CODE': '2195',
#    'STOP_NAME': 'NEWKIRK RD STOP # 2195',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43185299999999, 43.886765000000025]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1102,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2432',
#    'CODE': '2432',
#    'STOP_NAME': 'SANDFORD ST / SAVAGE RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47000699999995, 44.03368100000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1103,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2431',
#    'CODE': '2431',
#    'STOP_NAME': 'SANDFORD ST / STELLICK AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46844499999997, 44.03574000000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1104,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6900',
#    'CODE': '6900',
#    'STOP_NAME': 'POETRY DR / FLOURISH ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.57250999999997, 43.84464600000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1105,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '9852',
#    'CODE': '9852',
#    'STOP_NAME': 'DAVIS DR / LESLIE ST',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43266699999998, 44.06576600000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1106,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2435',
#    'CODE': '2435',
#    'STOP_NAME': 'SAWMILL VALLEY DR / COLUMBUS WAY',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48067699999996, 44.03146400000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1107,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '2434',
#    'CODE': '2434',
#    'STOP_NAME': 'SAWMILL VALLEY DR / JOE PERSECHINI',
#    'DESCRIPTION': 'SAWMILL VALLEY DR & JOE PERSECHINI DR',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47783099999998, 44.03216500000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1108,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6459',
#    'CODE': '6459',
#    'STOP_NAME': 'DALTON RD STOP # 6459',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36851399999995, 44.317604000000074]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1109,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '3761',
#    'CODE': '3761',
#    'STOP_NAME': 'WESTON RD / RUTHERFORD RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55651599999999, 43.82662000000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1110,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4203',
#    'CODE': '4203',
#    'STOP_NAME': 'DON MILLS RD / CLIFFWOOD RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.35701599999999, 43.807101000000046]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1111,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1161',
#    'CODE': '1161',
#    'STOP_NAME': 'MURRAY DR / CORBETT CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47192299999995, 43.98383200000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1112,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6953',
#    'CODE': '6953',
#    'STOP_NAME': 'NAPA VALLEY AV / FOREST FOUNTAIN DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.61313199999995, 43.82449100000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1113,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '5764',
#    'CODE': '5764',
#    'STOP_NAME': 'ELSON ST / EASTVALE DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24782599999998, 43.842224000000044]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1114,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6341',
#    'CODE': '6341',
#    'STOP_NAME': 'MAJOR MACKENZIE DR / VIA ROMANO BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46844599999997, 43.86489800000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1115,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6340',
#    'CODE': '6340',
#    'STOP_NAME': 'GAMBLE RD / COLESBROOK RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46008399999994, 43.90476000000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1116,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4518',
#    'CODE': '4518',
#    'STOP_NAME': 'NORTH LAKE RD / LAKELAND CRES',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44148399999995, 43.95139000000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1117,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4519',
#    'CODE': '4519',
#    'STOP_NAME': 'JEFFERSON FOREST DR / ARDEN VALLEY',
#    'DESCRIPTION': 'JEFFERSON FOREST DR & ARDEN VALLEY ST',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44136599999996, 43.91553700000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1118,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6345',
#    'CODE': '6345',
#    'STOP_NAME': 'BATHURST ST / NER ISRAEL DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45686799999999, 43.839874000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1119,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '6344',
#    'CODE': '6344',
#    'STOP_NAME': 'MINTHORN CT / COMMERCE VALLEY DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37672599999996, 43.843372000000045]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1120,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6347',
#    'CODE': '6347',
#    'STOP_NAME': 'JANE ST / CIDERMILL AV',
#    'DESCRIPTION': 'JANE ST & CIDERMILL AVE',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.52694599999995, 43.80620600000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1121,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '6346',
#    'CODE': '6346',
#    'STOP_NAME': 'JANE ST / MACINTOSH BLVD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
# ...
#    'CODE': '3002',
#    'STOP_NAME': '16TH AV / THE BRIDLE WALK',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.29905499999995, 43.883050000000026]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1962,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '1985',
#    'CODE': '1985',
#    'STOP_NAME': 'YONGE ST / GLADMAN AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47929799999997, 44.04954600000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1963,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5589',
#    'CODE': '5589',
#    'STOP_NAME': 'PUGSLEY AV / ROSEVIEW AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43176699999998, 43.875001000000054]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1964,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '3009',
#    'CODE': '3009',
#    'STOP_NAME': '16TH AV / WARDEN AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.33831699999996, 43.87414800000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1965,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '7029',
#    'CODE': '7029',
#    'STOP_NAME': 'CASTLEMORE RD / APPLE VALLEY WAY',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.67489799999998, 43.80201800000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1966,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '2414',
#    'CODE': '2414',
#    'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2414',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46119899999997, 44.01117100000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1967,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '7203_merge',
#    'CODE': '7203',
#    'STOP_NAME': 'SMARTCENTRES PLACE BUS TERMINAL',
#    'DESCRIPTION': 'SMARTCENTRES PLACE BUS TERMINAL & PLATFORM 3',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.52749699999998, 43.79502300000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1968,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1588',
#    'CODE': '1588',
#    'STOP_NAME': 'RODICK RD / WOODBINE AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36416299999996, 43.87699500000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1969,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '5484',
#    'CODE': '5484',
#    'STOP_NAME': 'BOX GROVE BYP / 14TH AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22407099999998, 43.86060500000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1970,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7159',
#    'CODE': '7159',
#    'STOP_NAME': 'EDGLEY BLVD / APPLEWOOD CRES',
#    'DESCRIPTION': 'EDGELEY BLVD & APPLEWOOD CRES',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.53657099999998, 43.808073000000036]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1971,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7157',
#    'CODE': '7157',
#    'STOP_NAME': 'NINTH LINE / 14TH AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22997899999996, 43.85942000000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1972,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5483',
#    'CODE': '5483',
#    'STOP_NAME': 'RIVERWALK DR / BOX GROVE BYP',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22158699999994, 43.85822500000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1973,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '7155',
#    'CODE': '7155',
#    'STOP_NAME': 'KING ST / VISCOUNT WAY',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30148899999995, 44.14052000000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1974,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1581',
#    'CODE': '1581',
#    'STOP_NAME': 'ROUGE BANK DR / SILVERFLOWER AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24030099999999, 43.86122100000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1975,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '1586',
#    'CODE': '1586',
#    'STOP_NAME': 'RODICK RD / PILGRIM DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36093699999998, 43.877293000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1976,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '1587',
#    'CODE': '1587',
#    'STOP_NAME': 'BOXWOOD CRES / LEMSFORD DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.23821499999997, 43.855653000000075]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1977,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '1584',
#    'CODE': '1584',
#    'STOP_NAME': 'RODICK RD / MACRILL RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.35822799999994, 43.87627800000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1978,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '3314',
#    'CODE': '3314',
#    'STOP_NAME': 'BATHURST ST / MILNER GATE',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44765399999994, 43.799660000000074]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1979,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '1038',
#    'CODE': '1038',
#    'STOP_NAME': 'VALLEYMEDE DR / CHALMERS RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39893499999994, 43.84564500000005]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1980,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1039',
#    'CODE': '1039',
#    'STOP_NAME': 'DONCASTER AV / HENDERSON AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.40916399999998, 43.806107000000054]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1981,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5481',
#    'CODE': '5481',
#    'STOP_NAME': 'BOX GROVE BYP / RIZAL AV',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22519999999997, 43.862520000000075]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1982,
#    'WHEELCHAIR_BOARDING': 'No',
#    'STOP_ID': '9808_merge',
#    'CODE': '9808',
#    'STOP_NAME': 'YONGE ST / EAGLE ST',
#    'DESCRIPTION': '17150 Yonge St YONGE ST & EAGLE ST',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47803799999997, 44.04484000000008]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1983,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1032',
#    'CODE': '1032',
#    'STOP_NAME': 'VALLEYMEDE DR / SAMANTHA CIR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39212599999996, 43.843585000000076]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1984,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1033',
#    'CODE': '1033',
#    'STOP_NAME': 'DONCASTER AV STOP # 1033',
#    'DESCRIPTION': 'DONCASTER AV STOP #1033',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41559899999999, 43.80407800000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1985,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1030',
#    'CODE': '1030',
#    'STOP_NAME': 'TIMES AV / HIGHWAY 7',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39153899999997, 43.84196000000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1986,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '5480',
#    'CODE': '5480',
#    'STOP_NAME': 'BOX GROVE BYPASS/ COPPER CREEK DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.23063599999995, 43.86595700000004]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1987,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1036',
#    'CODE': '1036',
#    'STOP_NAME': 'VALLEYMEDE DR / LEICESTER RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39602899999994, 43.84553800000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1988,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1037',
#    'CODE': '1037',
#    'STOP_NAME': 'DONCASTER AV STOP # 1037',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41150499999998, 43.80533400000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1989,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1034',
#    'CODE': '1034',
#    'STOP_NAME': 'VALLEYMEDE DR / RED OAK DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39301399999994, 43.84571900000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1990,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1035',
#    'CODE': '1035',
#    'STOP_NAME': 'DONCASTER AV STOP # 1035',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41394799999995, 43.80459200000007]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1991,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1213',
#    'CODE': '1213',
#    'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 3',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42624899999998, 43.87626000000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1992,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1210',
#    'CODE': '1210',
#    'STOP_NAME': 'AURORA HEIGHTS DR / WHISPERING PINE',
#    'DESCRIPTION': 'AURORA HEIGHTS DR & WHISPERING PINE TRL',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49281899999994, 43.99857000000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1993,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1211',
#    'CODE': '1211',
#    'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 2',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42603199999996, 43.876306000000056]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1994,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1216',
#    'CODE': '1216',
#    'STOP_NAME': 'ORCHARD HEIGHTS BLVD / FIELDING DR',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49004299999996, 44.00490700000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1995,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1217',
#    'CODE': '1217',
#    'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 5',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42665999999997, 43.876112000000035]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1996,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1214',
#    'CODE': '1214',
#    'STOP_NAME': 'ORCHARD HEIGHTS BLVD / WHISPERING P',
#    'DESCRIPTION': 'ORCHARD HEIGHTS BLVD & WHISPERING PINE TRL',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.49423399999995, 44.002379000000076]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1997,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1215',
#    'CODE': '1215',
#    'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 4',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42646199999996, 43.876212000000066]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1998,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1218',
#    'CODE': '1218',
#    'STOP_NAME': 'ORCHARD HEIGHTS BLVD / CRAWFORD ROS',
#    'DESCRIPTION': 'ORCHARD HEIGHTS BLVD & CRAWFORD ROSE DR',
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.48652299999998, 44.00564900000006]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 1999,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '1219',
#    'CODE': '1219',
#    'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 6',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42618799999997, 43.87588800000003]}},
#  {'type': 'Feature',
#   'properties': {'OBJECTID': 2000,
#    'WHEELCHAIR_BOARDING': 'Yes / Part',
#    'STOP_ID': '4245',
#    'CODE': '4245',
#    'STOP_NAME': 'LANGSTAFF RD / WESTON RD',
#    'DESCRIPTION': None,
#    'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#    'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55156999999997, 43.808107000000064]}},
#  ...]

# %%
bus_routes_resp = requests.get('https://opendata.arcgis.com/datasets/ca904f8425814759a3dfa5951afff479_2.geojson')

bus_routes = json.loads(bus_routes_resp.text)

# %%
bus_routes
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1001,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4692',
#     'CODE': '4692',
#     'STOP_NAME': 'YONGE ST / WRIGHT ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43897999999996, 43.87812100000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1002,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7268',
#     'CODE': '7268',
#     'STOP_NAME': 'MURRELL BLVD / APPLEGATE DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44869399999999, 44.08571200000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1003,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6424',
#     'CODE': '6424',
#     'STOP_NAME': 'AURORA GO STATION PLATFORM 2',
#     'DESCRIPTION': 'AURORA GO STATION & PLATFORM #2',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45949999999993, 44.00016000000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1004,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6425',
#     'CODE': '6425',
#     'STOP_NAME': 'INDUSTRIAL PKWY / YONGE ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46227899999997, 43.98118100000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1005,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6426',
#     'CODE': '6426',
#     'STOP_NAME': 'NEWMARKET GO PLATFORM 10',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48615299999994, 44.05278000000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1006,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1680',
#     'CODE': '1680',
#     'STOP_NAME': 'MAJOR MACKENZIE DR / WOODBINE AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36777999999998, 43.885680000000036]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1007,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6420',
#     'CODE': '6420',
#     'STOP_NAME': 'DUFFIELD DR / KENNEDY RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30663099999998, 43.845769000000075]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1008,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4298',
#     'CODE': '4298',
#     'STOP_NAME': 'HIGHWAY 7 / RODICK RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.34580599999998, 43.852697000000035]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1009,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6422',
#     'CODE': '6422',
#     'STOP_NAME': 'MAIN ST / 10TH LINE',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.23218499999996, 43.97456600000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1010,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6423',
#     'CODE': '6423',
#     'STOP_NAME': 'AURORA GO STATION PLATFORM 3',
#     'DESCRIPTION': 'AURORA GO STATION & PLATFORM #3',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45941099999999, 43.99988100000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1011,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4295',
#     'CODE': '4295',
#     'STOP_NAME': 'ASHBERRY BLVD / WESTON RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55730699999998, 43.83462600000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1012,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4297',
#     'CODE': '4297',
#     'STOP_NAME': 'ASHBERRY BLVD / OLAND DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55473499999994, 43.83509300000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1013,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1423',
#     'CODE': '1423',
#     'STOP_NAME': 'RODICK RD / RACHEL CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36223399999994, 43.877080000000035]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1014,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6428',
#     'CODE': '6428',
#     'STOP_NAME': 'METRO RD / LENNOX AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47218899999996, 44.297308000000044]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1015,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6429',
#     'CODE': '6429',
#     'STOP_NAME': 'HIGH ST / DALTON RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36214299999995, 44.30460000000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1016,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2972',
#     'CODE': '2972',
#     'STOP_NAME': 'RIDGECREST RD / MAJOR MACKENZIE DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30452499999996, 43.90035900000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1017,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6412',
#     'CODE': '6412',
#     'STOP_NAME': 'MULOCK DR / COLUMBUS WAY',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48168899999996, 44.03496000000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1018,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '9851',
#     'CODE': '9851',
#     'STOP_NAME': 'DAVIS DR / LESLIE ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43120399999998, 44.06588400000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1019,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4695',
#     'CODE': '4695',
#     'STOP_NAME': 'YONGE ST / HIGH TECH RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43037999999996, 43.84161700000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1020,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7267',
#     'CODE': '7267',
#     'STOP_NAME': 'JANE ST / FREDERICK BANTING ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.53726499999993, 43.85165400000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1021,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7266',
#     'CODE': '7266',
#     'STOP_NAME': 'JANE ST / FREDERICK BANTING ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.53679399999999, 43.85100900000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1022,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2590',
#     'CODE': '2590',
#     'STOP_NAME': "DAVIS DR / LUNDY'S LANE",
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45361399999996, 44.06091200000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1023,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7261',
#     'CODE': '7261',
#     'STOP_NAME': 'VICTORIA ST / CHURCH ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46515299999999, 43.99718000000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1024,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6169',
#     'CODE': '6169',
#     'STOP_NAME': 'YONGE ST / HOMEWOOD AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41862499999996, 43.79128900000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1025,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6168',
#     'CODE': '6168',
#     'STOP_NAME': 'WOODBINE AV / ELGIN MILLS RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37825799999996, 43.903001000000074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1026,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6161',
#     'CODE': '6161',
#     'STOP_NAME': 'HAZELTON AV / VINE CLIFF BLVD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36592199999996, 43.893770000000075]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1027,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1971',
#     'CODE': '1971',
#     'STOP_NAME': 'UPPER CANADA MALL STOP # 1971',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48616999999996, 44.054512000000045]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1028,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6163',
#     'CODE': '6163',
#     'STOP_NAME': 'STONY HILL BLVD / VICTORIA SQUARE B',
#     'DESCRIPTION': 'STONY HILL BLVD & VICTORIA SQUARE BLVD',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36952999999994, 43.89677800000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1029,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6162',
#     'CODE': '6162',
#     'STOP_NAME': 'HAZELTON AV / STONY HILL BLVD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36760799999996, 43.896948000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1030,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6165',
#     'CODE': '6165',
#     'STOP_NAME': 'WOODBINE AV / PRINCE OF WALES',
#     'DESCRIPTION': 'WOODBINE AV & PRINCE OF WALES DR',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37893799999995, 43.90532600000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1031,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6167',
#     'CODE': '6167',
#     'STOP_NAME': 'WOODBINE AV / LORD MELBORNE ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37952799999994, 43.905808000000036]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1032,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6166',
#     'CODE': '6166',
#     'STOP_NAME': 'HONDA STOP # 6166',
#     'DESCRIPTION': 'HONDA PLANT & BESIDE MAIN ENTRANCE',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.38411999999994, 43.91359700000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1033,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4749',
#     'CODE': '4749',
#     'STOP_NAME': 'WELLINGTON ST / WELLS ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46392099999997, 44.00048900000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1034,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4748',
#     'CODE': '4748',
#     'STOP_NAME': 'WELLINGTON ST / MCDONALD DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48000899999994, 43.99704600000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1035,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6769',
#     'CODE': '6769',
#     'STOP_NAME': 'BAYVIEW AV / SUMMIT TRAIL DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42553399999997, 43.91732500000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1036,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6768',
#     'CODE': '6768',
#     'STOP_NAME': 'CALDARI RD / GRANITERIDGE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.52996899999994, 43.82551600000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1037,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4743',
#     'CODE': '4743',
#     'STOP_NAME': 'CONOVER AV / STARR CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44397399999997, 44.01799300000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1038,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4742',
#     'CODE': '4742',
#     'STOP_NAME': 'HARTWELL WAY / BAYVIEW AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44656699999996, 44.019296000000054]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1039,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4741',
#     'CODE': '4741',
#     'STOP_NAME': 'BAYVIEW AV / HARTWELL WAY',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44673299999994, 44.018976000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1040,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4740',
#     'CODE': '4740',
#     'STOP_NAME': 'GATEWAY DR / KIRKVALLEY CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45486499999998, 44.01697900000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1041,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4747',
#     'CODE': '4747',
#     'STOP_NAME': 'WELLINGTON ST / HILLDALE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48308899999995, 43.99638100000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1042,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4746',
#     'CODE': '4746',
#     'STOP_NAME': 'WELLINGTON ST / MCLEOD DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48670399999997, 43.99563900000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1043,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4745',
#     'CODE': '4745',
#     'STOP_NAME': 'WELLINGTON ST / BATHURST ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49287799999996, 43.994429000000025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1044,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4744',
#     'CODE': '4744',
#     'STOP_NAME': 'CONOVER AV / BROOKS AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44286399999999, 44.01456300000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1045,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6887',
#     'CODE': '6887',
#     'STOP_NAME': 'KEELE ST STOP # 6887',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.51552899999996, 43.86931400000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1046,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7291',
#     'CODE': '7291',
#     'STOP_NAME': 'HIGHWAY 7 / WHITMORE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55647599999998, 43.78742700000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1047,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5869',
#     'CODE': '5869',
#     'STOP_NAME': 'WESTON RD / MAJOR MACKENZIE DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.56057999999996, 43.84417300000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1048,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5868',
#     'CODE': '5868',
#     'STOP_NAME': 'RUTHERFORD RD / CRIMSON FOREST DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47632499999997, 43.844183000000044]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1049,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4697',
#     'CODE': '4697',
#     'STOP_NAME': 'HIGHWAY 7 STOP # 4697',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.23910499999994, 43.87889400000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1050,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '5865',
#     'CODE': '5865',
#     'STOP_NAME': 'LARKIN AV / SAWYER CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.24041999999997, 43.89343900000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1051,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6200',
#     'CODE': '6200',
#     'STOP_NAME': 'ZENWAY BLVD / NEW HUNTINGTON RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.64421199999998, 43.77495400000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1052,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5867',
#     'CODE': '5867',
#     'STOP_NAME': 'RUTHERFORD RD / BLUE GROUSE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47303999999997, 43.84485100000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1053,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '5866',
#     'CODE': '5866',
#     'STOP_NAME': 'RAVENSHOE RD STOP # 5866',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47220099999998, 44.191636000000074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1054,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5861',
#     'CODE': '5861',
#     'STOP_NAME': 'WOODSPRING AV / FORD WILSON BLVD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49945499999995, 44.05617900000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1055,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '5860',
#     'CODE': '5860',
#     'STOP_NAME': 'METRO RD / GARDEN AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46764299999995, 44.23523200000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1056,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5863',
#     'CODE': '5863',
#     'STOP_NAME': 'ELGIN MILLS RD / PRINCE REGENT ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37515399999995, 43.90325100000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1057,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5862',
#     'CODE': '5862',
#     'STOP_NAME': 'WOODSPRING AV / ART WEST AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49974599999996, 44.05625400000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1058,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6950',
#     'CODE': '6950',
#     'STOP_NAME': 'DAVIS DR / FORHAN AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42991199999994, 44.06611600000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1059,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1424',
#     'CODE': '1424',
#     'STOP_NAME': 'CLARK AV / HILDA AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43708899999996, 43.80553500000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1060,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2331',
#     'CODE': '2331',
#     'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 11',
#     'DESCRIPTION': 'PLATFORM # 11',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41551199999998, 43.782425000000046]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1061,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5350',
#     'CODE': '5350',
#     'STOP_NAME': 'PEARSON AV STOP # 5350',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43706499999996, 43.83926800000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1062,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6796',
#     'CODE': '6796',
#     'STOP_NAME': 'METRO RD / CHARLES CRES',
#     'DESCRIPTION': 'METRO RD & NEW FOREST LN',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48486299999996, 44.25802900000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1063,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2183',
#     'CODE': '2183',
#     'STOP_NAME': 'WELDRICK RD STOP # 2183',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43257699999998, 43.860876000000076]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1064,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2333',
#     'CODE': '2333',
#     'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 14',
#     'DESCRIPTION': 'PLATFORM # 14',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41530499999999, 43.78250300000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1065,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2187',
#     'CODE': '2187',
#     'STOP_NAME': 'ESSEX AV / PALISER CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42314899999997, 43.86872600000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1066,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2186',
#     'CODE': '2186',
#     'STOP_NAME': 'WELDRICK RD / ESSEX AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42182899999995, 43.86697600000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1067,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2185',
#     'CODE': '2185',
#     'STOP_NAME': 'WELDRICK RD STOP # 2185',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42718999999994, 43.86579300000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1068,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2184',
#     'CODE': '2184',
#     'STOP_NAME': 'WELDRICK RD / CHURCH ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43135299999994, 43.863215000000025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1069,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2189',
#     'CODE': '2189',
#     'STOP_NAME': 'ESSEX AV / ELMWOOD AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42370799999998, 43.87204100000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1070,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2188',
#     'CODE': '2188',
#     'STOP_NAME': 'ESSEX AV / PALMER AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42356599999994, 43.870179000000064]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1071,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4602',
#     'CODE': '4602',
#     'STOP_NAME': 'TIERRA AV / TREASURE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.54410699999994, 43.85646900000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1072,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4603',
#     'CODE': '4603',
#     'STOP_NAME': 'SILVERWOOD AV / YORKLAND ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44033499999995, 43.899402000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1073,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '4600',
#     'CODE': '4600',
#     'STOP_NAME': 'MAPLE SUGAR LANE / THORNHILL WOODS',
#     'DESCRIPTION': 'MAPLE SUGAR LANE & THORNHILL WOODS DR',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46486599999997, 43.82700500000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1074,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2335',
#     'CODE': '2335',
#     'STOP_NAME': 'FINCH GO BUS TERMINAL PLATFORM 16',
#     'DESCRIPTION': 'PLATFORM # 16',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41463199999998, 43.782515000000046]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1075,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2213',
#     'CODE': '2213',
#     'STOP_NAME': 'INDUSTRIAL PKWY / ENGLEHARD DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45386499999995, 43.990368000000046]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1076,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2212',
#     'CODE': '2212',
#     'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2212',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45498099999998, 43.99276700000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1077,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2211',
#     'CODE': '2211',
#     'STOP_NAME': 'INDUSTRIAL PKWY / MARY ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45862599999998, 43.99863700000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1078,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2210',
#     'CODE': '2210',
#     'STOP_NAME': 'ELGIN MILLS RD / REGENT ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45250999999996, 43.88715200000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1079,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2216',
#     'CODE': '2216',
#     'STOP_NAME': 'INDUSTRIAL PKWY / VANDORF SDRD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45547499999998, 43.98363200000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1080,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2215',
#     'CODE': '2215',
#     'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2215',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45436899999999, 43.98609800000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1081,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2214',
#     'CODE': '2214',
#     'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2214',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45353799999998, 43.98822700000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1082,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2680',
#     'CODE': '2680',
#     'STOP_NAME': 'ROLLINGHILL RD / SKYWOOD DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45962399999996, 43.91119400000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1083,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2219',
#     'CODE': '2219',
#     'STOP_NAME': 'BAYVIEW AV / SPRING FARM RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44593099999997, 44.015370000000075]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1084,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6453',
#     'CODE': '6453',
#     'STOP_NAME': 'METRO RD / RAINES ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49763899999994, 44.27209000000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1085,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6209',
#     'CODE': '6209',
#     'STOP_NAME': 'OLD COLONY RD / CAROUSEL CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45289299999996, 43.93990500000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1086,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2338',
#     'CODE': '2338',
#     'STOP_NAME': 'YONGE ST / CUMMER AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41733499999998, 43.787532000000056]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1087,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6699',
#     'CODE': '6699',
#     'STOP_NAME': 'HIGHWAY 50 / RUTHERFORD RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.66726499999999, 43.80321500000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1088,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6698',
#     'CODE': '6698',
#     'STOP_NAME': 'HOLLANDVIEW TRL / BRIDGENORTH DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45304299999998, 44.01370200000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1089,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2339',
#     'CODE': '2339',
#     'STOP_NAME': 'YONGE ST / OTONABEE AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41899399999994, 43.794272000000035]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1090,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6693',
#     'CODE': '6693',
#     'STOP_NAME': 'ILAN RAMON BLVD / GEORGE KIRBY ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46304899999996, 43.84998000000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1091,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6692',
#     'CODE': '6692',
#     'STOP_NAME': 'BOX GROVE BYPASS / 14TH AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.22446899999994, 43.861015000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1092,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6691',
#     'CODE': '6691',
#     'STOP_NAME': 'THE BRIDLE WALK / MADISON HEIGHTS',
#     'DESCRIPTION': 'THE BRIDLE WAK & MADISON HEIGHTS BLVD',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30440299999998, 43.89042400000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1093,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6690',
#     'CODE': '6690',
#     'STOP_NAME': 'THE BRIDLE WALK / HOLST AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30379599999998, 43.88957700000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1094,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6697',
#     'CODE': '6697',
#     'STOP_NAME': 'JANE ST STOP # 6697',
#     'DESCRIPTION': 'JANE ST & RUTHERFORD RD',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.53341099999994, 43.83319700000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1095,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6696',
#     'CODE': '6696',
#     'STOP_NAME': 'JANE ST / RUTHERFORD RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.53295999999995, 43.83299000000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1096,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6695',
#     'CODE': '6695',
#     'STOP_NAME': 'ILAN RAMON BLVD / RUTHERFORD RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46233599999994, 43.84812400000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1097,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6694',
#     'CODE': '6694',
#     'STOP_NAME': 'ILAN RAMON BLVD / MARC SANTI BLVD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46364899999998, 43.85164000000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1098,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1426',
#     'CODE': '1426',
#     'STOP_NAME': 'CLARK AV / CHARLES ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43329199999994, 43.80640800000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1099,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2439',
#     'CODE': '2439',
#     'STOP_NAME': 'MULOCK DR / YONGE ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47628799999995, 44.03608900000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1100,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '9856',
#     'CODE': '9856',
#     'STOP_NAME': 'DAVIS DR / HIGHWAY 404',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42110399999996, 44.06762700000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1101,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2195',
#     'CODE': '2195',
#     'STOP_NAME': 'NEWKIRK RD STOP # 2195',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43185299999999, 43.886765000000025]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1102,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2432',
#     'CODE': '2432',
#     'STOP_NAME': 'SANDFORD ST / SAVAGE RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47000699999995, 44.03368100000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1103,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2431',
#     'CODE': '2431',
#     'STOP_NAME': 'SANDFORD ST / STELLICK AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46844499999997, 44.03574000000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1104,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6900',
#     'CODE': '6900',
#     'STOP_NAME': 'POETRY DR / FLOURISH ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.57250999999997, 43.84464600000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1105,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '9852',
#     'CODE': '9852',
#     'STOP_NAME': 'DAVIS DR / LESLIE ST',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43266699999998, 44.06576600000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1106,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2435',
#     'CODE': '2435',
#     'STOP_NAME': 'SAWMILL VALLEY DR / COLUMBUS WAY',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48067699999996, 44.03146400000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1107,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '2434',
#     'CODE': '2434',
#     'STOP_NAME': 'SAWMILL VALLEY DR / JOE PERSECHINI',
#     'DESCRIPTION': 'SAWMILL VALLEY DR & JOE PERSECHINI DR',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47783099999998, 44.03216500000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1108,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6459',
#     'CODE': '6459',
#     'STOP_NAME': 'DALTON RD STOP # 6459',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36851399999995, 44.317604000000074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1109,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '3761',
#     'CODE': '3761',
#     'STOP_NAME': 'WESTON RD / RUTHERFORD RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55651599999999, 43.82662000000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1110,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4203',
#     'CODE': '4203',
#     'STOP_NAME': 'DON MILLS RD / CLIFFWOOD RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.35701599999999, 43.807101000000046]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1111,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1161',
#     'CODE': '1161',
#     'STOP_NAME': 'MURRAY DR / CORBETT CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47192299999995, 43.98383200000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1112,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '6953',
#     'CODE': '6953',
#     'STOP_NAME': 'NAPA VALLEY AV / FOREST FOUNTAIN DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.61313199999995, 43.82449100000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1113,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '5764',
#     'CODE': '5764',
#     'STOP_NAME': 'ELSON ST / EASTVALE DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.24782599999998, 43.842224000000044]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1114,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6341',
#     'CODE': '6341',
#     'STOP_NAME': 'MAJOR MACKENZIE DR / VIA ROMANO BLVD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46844599999997, 43.86489800000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1115,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6340',
#     'CODE': '6340',
#     'STOP_NAME': 'GAMBLE RD / COLESBROOK RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46008399999994, 43.90476000000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1116,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4518',
#     'CODE': '4518',
#     'STOP_NAME': 'NORTH LAKE RD / LAKELAND CRES',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44148399999995, 43.95139000000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1117,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4519',
#     'CODE': '4519',
#     'STOP_NAME': 'JEFFERSON FOREST DR / ARDEN VALLEY',
#     'DESCRIPTION': 'JEFFERSON FOREST DR & ARDEN VALLEY ST',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44136599999996, 43.91553700000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1118,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '6345',
#     'CODE': '6345',
# ...
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47929799999997, 44.04954600000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1963,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5589',
#     'CODE': '5589',
#     'STOP_NAME': 'PUGSLEY AV / ROSEVIEW AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43176699999998, 43.875001000000054]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1964,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '3009',
#     'CODE': '3009',
#     'STOP_NAME': '16TH AV / WARDEN AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.33831699999996, 43.87414800000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1965,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '7029',
#     'CODE': '7029',
#     'STOP_NAME': 'CASTLEMORE RD / APPLE VALLEY WAY',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.67489799999998, 43.80201800000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1966,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '2414',
#     'CODE': '2414',
#     'STOP_NAME': 'INDUSTRIAL PKWY STOP # 2414',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.46119899999997, 44.01117100000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1967,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '7203_merge',
#     'CODE': '7203',
#     'STOP_NAME': 'SMARTCENTRES PLACE BUS TERMINAL',
#     'DESCRIPTION': 'SMARTCENTRES PLACE BUS TERMINAL & PLATFORM 3',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.52749699999998, 43.79502300000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1968,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1588',
#     'CODE': '1588',
#     'STOP_NAME': 'RODICK RD / WOODBINE AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36416299999996, 43.87699500000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1969,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '5484',
#     'CODE': '5484',
#     'STOP_NAME': 'BOX GROVE BYP / 14TH AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.22407099999998, 43.86060500000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1970,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7159',
#     'CODE': '7159',
#     'STOP_NAME': 'EDGLEY BLVD / APPLEWOOD CRES',
#     'DESCRIPTION': 'EDGELEY BLVD & APPLEWOOD CRES',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.53657099999998, 43.808073000000036]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1971,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7157',
#     'CODE': '7157',
#     'STOP_NAME': 'NINTH LINE / 14TH AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.22997899999996, 43.85942000000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1972,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5483',
#     'CODE': '5483',
#     'STOP_NAME': 'RIVERWALK DR / BOX GROVE BYP',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.22158699999994, 43.85822500000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1973,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '7155',
#     'CODE': '7155',
#     'STOP_NAME': 'KING ST / VISCOUNT WAY',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30148899999995, 44.14052000000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1974,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1581',
#     'CODE': '1581',
#     'STOP_NAME': 'ROUGE BANK DR / SILVERFLOWER AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.24030099999999, 43.86122100000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1975,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '1586',
#     'CODE': '1586',
#     'STOP_NAME': 'RODICK RD / PILGRIM DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36093699999998, 43.877293000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1976,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '1587',
#     'CODE': '1587',
#     'STOP_NAME': 'BOXWOOD CRES / LEMSFORD DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.23821499999997, 43.855653000000075]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1977,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '1584',
#     'CODE': '1584',
#     'STOP_NAME': 'RODICK RD / MACRILL RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.35822799999994, 43.87627800000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1978,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '3314',
#     'CODE': '3314',
#     'STOP_NAME': 'BATHURST ST / MILNER GATE',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44765399999994, 43.799660000000074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1979,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '1038',
#     'CODE': '1038',
#     'STOP_NAME': 'VALLEYMEDE DR / CHALMERS RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39893499999994, 43.84564500000005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1980,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1039',
#     'CODE': '1039',
#     'STOP_NAME': 'DONCASTER AV / HENDERSON AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40916399999998, 43.806107000000054]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1981,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5481',
#     'CODE': '5481',
#     'STOP_NAME': 'BOX GROVE BYP / RIZAL AV',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.22519999999997, 43.862520000000075]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1982,
#     'WHEELCHAIR_BOARDING': 'No',
#     'STOP_ID': '9808_merge',
#     'CODE': '9808',
#     'STOP_NAME': 'YONGE ST / EAGLE ST',
#     'DESCRIPTION': '17150 Yonge St YONGE ST & EAGLE ST',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47803799999997, 44.04484000000008]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1983,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1032',
#     'CODE': '1032',
#     'STOP_NAME': 'VALLEYMEDE DR / SAMANTHA CIR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39212599999996, 43.843585000000076]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1984,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1033',
#     'CODE': '1033',
#     'STOP_NAME': 'DONCASTER AV STOP # 1033',
#     'DESCRIPTION': 'DONCASTER AV STOP #1033',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41559899999999, 43.80407800000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1985,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1030',
#     'CODE': '1030',
#     'STOP_NAME': 'TIMES AV / HIGHWAY 7',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39153899999997, 43.84196000000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1986,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '5480',
#     'CODE': '5480',
#     'STOP_NAME': 'BOX GROVE BYPASS/ COPPER CREEK DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.23063599999995, 43.86595700000004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1987,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1036',
#     'CODE': '1036',
#     'STOP_NAME': 'VALLEYMEDE DR / LEICESTER RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39602899999994, 43.84553800000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1988,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1037',
#     'CODE': '1037',
#     'STOP_NAME': 'DONCASTER AV STOP # 1037',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41150499999998, 43.80533400000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1989,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1034',
#     'CODE': '1034',
#     'STOP_NAME': 'VALLEYMEDE DR / RED OAK DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.39301399999994, 43.84571900000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1990,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1035',
#     'CODE': '1035',
#     'STOP_NAME': 'DONCASTER AV STOP # 1035',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.41394799999995, 43.80459200000007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1991,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1213',
#     'CODE': '1213',
#     'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 3',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42624899999998, 43.87626000000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1992,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1210',
#     'CODE': '1210',
#     'STOP_NAME': 'AURORA HEIGHTS DR / WHISPERING PINE',
#     'DESCRIPTION': 'AURORA HEIGHTS DR & WHISPERING PINE TRL',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49281899999994, 43.99857000000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1993,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1211',
#     'CODE': '1211',
#     'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 2',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42603199999996, 43.876306000000056]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1994,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1216',
#     'CODE': '1216',
#     'STOP_NAME': 'ORCHARD HEIGHTS BLVD / FIELDING DR',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49004299999996, 44.00490700000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1995,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1217',
#     'CODE': '1217',
#     'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 5',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42665999999997, 43.876112000000035]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1996,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1214',
#     'CODE': '1214',
#     'STOP_NAME': 'ORCHARD HEIGHTS BLVD / WHISPERING P',
#     'DESCRIPTION': 'ORCHARD HEIGHTS BLVD & WHISPERING PINE TRL',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.49423399999995, 44.002379000000076]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1997,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1215',
#     'CODE': '1215',
#     'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 4',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42646199999996, 43.876212000000066]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1998,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1218',
#     'CODE': '1218',
#     'STOP_NAME': 'ORCHARD HEIGHTS BLVD / CRAWFORD ROS',
#     'DESCRIPTION': 'ORCHARD HEIGHTS BLVD & CRAWFORD ROSE DR',
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.48652299999998, 44.00564900000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 1999,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '1219',
#     'CODE': '1219',
#     'STOP_NAME': 'RICHMOND HILL GO STATION PLATFORM 6',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42618799999997, 43.87588800000003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2000,
#     'WHEELCHAIR_BOARDING': 'Yes / Part',
#     'STOP_ID': '4245',
#     'CODE': '4245',
#     'STOP_NAME': 'LANGSTAFF RD / WESTON RD',
#     'DESCRIPTION': None,
#     'SCHEDULE_START': '2019-11-03T00:00:00.000Z',
#     'SCHEDULE_END': '2019-12-21T00:00:00.000Z'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55156999999997, 43.808107000000064]}},
#   ...]}
